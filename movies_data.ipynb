# %%
import json
import pandas as pd

# %%
df = pd.read_json(r"D:\Projects\Databastyper\kunskapskontroll_1\data\movies\movies.json")

# %%
df.head(2)
# Out:
#    movie_id  color   director_name  num_critic_for_reviews  duration  \
# 0    499549  Color   James Cameron                   723.0     178.0
# 1    449088  Color  Gore Verbinski                   302.0     169.0
#
#          gross                                genres  \
# 0  760505847.0  [Action, Adventure, Fantasy, Sci-Fi]
# 1  309404152.0          [Action, Adventure, Fantasy]
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
#
#    facenumber_in_poster  ...  \
# 0                   0.0  ...
# 1                   0.0  ...
#
#                                      movie_imdb_link num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...               3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...               1238.0
#
#    language country content_rating       budget  title_year  imdb_score  \
# ...

# %%
df_exploded = df.explode("actors")

# %%
df_exploded.tail()
# Out:
#       movie_id  color director_name  num_critic_for_reviews  duration  \
# 4917   2070597  Color   Daniel Hsia                    14.0     100.0
# 4917   2070597  Color   Daniel Hsia                    14.0     100.0
# 4918    378407  Color      Jon Gunn                    43.0      90.0
# 4918    378407  Color      Jon Gunn                    43.0      90.0
# 4918    378407  Color      Jon Gunn                    43.0      90.0
#
#         gross                    genres         movie_title  num_voted_users  \
# 4917  10443.0  [Comedy, Drama, Romance]   Shanghai Calling              1255
# 4917  10443.0  [Comedy, Drama, Romance]   Shanghai Calling              1255
# 4918  85222.0             [Documentary]  My Date with Drew              4285
# 4918  85222.0             [Documentary]  My Date with Drew              4285
# 4918  85222.0             [Documentary]  My Date with Drew              4285
#
#       facenumber_in_poster  ...  \
# 4917                   5.0  ...
# ...

# %%
actors = df_exploded[["movie_id", "actors"]]
actors["actor_id"] = range(len(actors))
actors.set_index("actor_id", inplace=True)
# Out:
# C:\Users\New\AppData\Local\Temp\ipykernel_12796\546303560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actors["actor_id"] = range(len(actors))

# %%
actors.head()
# Out:
#           movie_id            actors
# actor_id
# 0           499549  Joel David Moore
# 1           499549       CCH Pounder
# 2           499549         Wes Studi
# 3           449088     Orlando Bloom
# 4           449088       Johnny Depp

# %%
actors_final = actors[["actors"]]

# %%
actors_final.reset_index(inplace=True)
actors_final.index.name = "actor_id"
actors_final.head()
# Out:
#           actor_id            actors
# actor_id
# 0                0  Joel David Moore
# 1                1       CCH Pounder
# 2                2         Wes Studi
# 3                3     Orlando Bloom
# 4                4       Johnny Depp

# %%
actors_final["actors"].to_csv("actors.csv", index = True)

# %%
actor_by_movie = actors[["movie_id"]]

# %%
actor_by_movie.to_csv("actor_by_movie.csv")

# %%
director = pd.DataFrame(df["director_name"])

# %%
director.drop_duplicates(inplace=True)

# %%
director.index.name = "director_id"
director.head(25)
# Out:
#                  director_name
# director_id
# 0                James Cameron
# 1               Gore Verbinski
# 2                   Sam Mendes
# 3            Christopher Nolan
# 4                  Doug Walker
# 5               Andrew Stanton
# 6                 Nathan Greno
# 7                  Joss Whedon
# 8                  David Yates
# 9                  Zack Snyder
# 10                Bryan Singer
# 11                Marc Forster
# 15              Andrew Adamson
# 16                Rob Marshall
# 17            Barry Sonnenfeld
# 18               Peter Jackson
# 19                   Marc Webb
# 20                Ridley Scott
# 22                 Chris Weitz
# 24               Anthony Russo
# 25                  Peter Berg
# 26             Colin Trevorrow
# 27                   Sam Raimi
# 28                 Shane Black
# 29                Brett Ratner

# %%
director["director_name"].to_csv("director.csv")

# %%
df_exploded2 = df.explode("genres")

# %%
genres = df_exploded2[["movie_id", "genres", "movie_id"]]

# %%
genres.index.name = "movie_id"
genres.tail()
# Out:
#           movie_id       genres  movie_id
# movie_id
# 4916       2107644     Thriller   2107644
# 4917       2070597       Comedy   2070597
# 4917       2070597        Drama   2070597
# 4917       2070597      Romance   2070597
# 4918        378407  Documentary    378407

# %%
genres_final = pd.DataFrame(genres["genres"].drop_duplicates())
genres_final.reset_index(inplace=True)
genres_final.index.name = "genres_id"

# %%
genres_final.head()
# Out:
#            movie_id     genres
# genres_id
# 0                 0     Action
# 1                 0  Adventure
# 2                 0    Fantasy
# 3                 0     Sci-Fi
# 4                 2   Thriller

# %%
genres_final["genres"].to_csv("genres.csv")

# %%
movies_rel = pd.DataFrame(df_exploded2["genres"])
movies_rel.head()
# Out:
#              genres
# movie_id
# 0            Action
# 0         Adventure
# 0           Fantasy
# 0            Sci-Fi
# 1            Action

# %%
movies_rel.reset_index(inplace=True)
movies_rel.index.name = "movie_id"
movies_rel.head()
# Out:
#           movie_id     genres
# movie_id
# 0                0     Action
# 1                0  Adventure
# 2                0    Fantasy
# 3                0     Sci-Fi
# 4                1     Action

# %%
genres_final.reset_index(inplace=True)
genres_final.index.name = "genres_id"
genres_final.head()
# Out:
#            genres_id  movie_id     genres
# genres_id
# 0                  0         0     Action
# 1                  1         0  Adventure
# 2                  2         0    Fantasy
# 3                  3         0     Sci-Fi
# 4                  4         2   Thriller

# %%
genres_by_movies = movies_rel.merge(genres_final, left_on="genres", right_on="genres")
genres_by_movies = genres_by_movies.drop(columns=["movie_id_y"])
genres_by_movies.head()
# Out:
#    movie_id_x     genres  genres_id
# 0           0     Action          0
# 1           0  Adventure          1
# 2           0    Fantasy          2
# 3           0     Sci-Fi          3
# 4           1     Action          0

# %%
genres_by_movies.set_index("movie_id_x", drop = True, inplace= True)
genres_by_movies.head()
# Out:
#                genres  genres_id
# movie_id_x
# 0              Action          0
# 0           Adventure          1
# 0             Fantasy          2
# 0              Sci-Fi          3
# 1              Action          0

# %%
genres_by_movies.index.rename("movie_id", inplace = True)
genres_by_movies["genres_id"].to_csv("movies_by_genres.csv")

# %%
movies = df[["movie_id", "director_name", "duration", "gross", "movie_title", "num_voted_users", "language", "country", "content_rating", "budget", "title_year", "imdb_score", "aspect_ratio"]]
movies = movies.drop(columns=["movie_id"])
movies.reset_index(inplace=True)
movies.index.rename("movie_id", inplace=True)

# %%
movies.head()
# Out:
#           index      director_name  duration        gross  \
# movie_id
# 0             0      James Cameron     178.0  760505847.0
# 1             1     Gore Verbinski     169.0  309404152.0
# 2             2         Sam Mendes     148.0  200074175.0
# 3             3  Christopher Nolan     164.0  448130642.0
# 4             4        Doug Walker       NaN          NaN
#
#                                                 movie_title  num_voted_users  \
# movie_id
# 0                                                   Avatar            886204
# 1                 Pirates of the Caribbean: At World's End            471220
# 2                                                  Spectre            275868
# 3                                    The Dark Knight Rises           1144337
# 4         Star Wars: Episode VII - The Force Awakens    ...                8
#
#          language country content_rating       budget  title_year  imdb_score  \
# movie_id
# ...

# %%
director.head()
# Out:
#                  director_name
# director_id
# 0                James Cameron
# 1               Gore Verbinski
# 2                   Sam Mendes
# 3            Christopher Nolan
# 4                  Doug Walker

# %%
director_fin = director.reset_index()
movies.reset_index()
movies_com = movies.merge(director_fin, on="director_name")
#movies_com = pd.concat([director, movies], keys=["director_name", "director_name"])

# %%
movies_com.reset_index(inplace=True)
movies_com.index.name = "movie_id"
movies_com.head(25)
# Out:
#           movie_id  level_0  index      director_name  duration        gross  \
# movie_id
# 0                0        0      0      James Cameron     178.0  760505847.0
# 1                1        1      1     Gore Verbinski     169.0  309404152.0
# 2                2        2      2         Sam Mendes     148.0  200074175.0
# 3                3        3      3  Christopher Nolan     164.0  448130642.0
# 4                4        4      4        Doug Walker       NaN          NaN
# 5                5        5      5     Andrew Stanton     132.0   73058679.0
# 6                6        6      6       Nathan Greno     100.0  200807262.0
# 7                7        7      7        Joss Whedon     141.0  458991599.0
# 8                8        8      8        David Yates     153.0  301956980.0
# 9                9        9      9        Zack Snyder     183.0  330249062.0
# 10              10       10     10       Bryan Singer     169.0  200069408.0
# ...

# %%
movies_com["director_id"].to_csv("director_by_move.csv")

# %%
movies_com[["duration", "gross", "movie_title", "num_voted_users", "language", "country", "content_rating", "budget", "title_year", "imdb_score", "aspect_ratio"]].to_csv("movies.csv")
